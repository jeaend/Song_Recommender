# %% [markdown]
# ### Objective
#
# Using spotipy API to retrieve songs from various playlists.
# First step is retrieving all categories and their id's.
# In order to not send too many API request of same nature, I am saving the intermediate result.
#
# *Output: 2_Category_Ids.csv*, columns 'category_id', 'category_name'

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time
import pandas as pd
from pandas import json_normalize

# %%
# retrieve secrets
def read_secrets(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        client_id = lines[0].strip().split(':')[1]
        client_secret = lines[1].strip().split(':')[1]
    return client_id, client_secret

# Read client ID and client secret from secrets.txt
client_id, client_secret = read_secrets('secrets.txt')

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %% [markdown]
# > retrieve available categories

# %%
all_category_ids = []

# Define the total number of categories you want to retrieve
total_categories = 100
categories_per_request = 50

# Iterate over multiple requests until the desired number of categories is reached
for offset in range(0, total_categories, categories_per_request):
    # Get categories with the current offset
    categories = sp.categories(country=None, locale=None, limit=categories_per_request, offset=offset)
    
    # Extract category IDs and add them to the list
    category_info = [(category['id'], category['name']) for category in categories['categories']['items']]
    all_category_ids.extend(category_info)

# %%
# Print the list of all category IDs
len(all_category_ids)
# Out:
# 55

# %%
all_category_ids
# Out:
# [('0JQ5DAt0tbjZptfcdMSKl3', 'Made For You'),
#  ('0JQ5DAqbMKFz6FAsUtgAab', 'New Releases'),
#  ('0JQ5DAqbMKFQ00XGBls6ym', 'Hip-Hop'),
#  ('0JQ5DAqbMKFEC4WFtoNRpw', 'Pop'),
#  ('0JQ5DAqbMKFzHmL4tf05da', 'Mood'),
#  ('0JQ5DAqbMKFDXXwE9BDJAr', 'Rock'),
#  ('0JQ5DAudkNjCgYMM0TZXDw', 'Charts'),
#  ('0JQ5DAqbMKFIRybaNTYXXy', 'In the car'),
#  ('0JQ5DAqbMKFHOzuVTgTizF', 'Dance/Electronic'),
#  ('0JQ5DAqbMKFFzDl7qN9Apr', 'Chill'),
#  ('0JQ5DAqbMKFCWjUTdzaG0e', 'Indie'),
#  ('0JQ5DAtOnAEpjOgUKwXyxj', 'Discover'),
#  ('0JQ5DAqbMKFImHYGo3eTSg', 'Fresh Finds'),
#  ('0JQ5DAqbMKFPw634sFwguI', 'EQUAL'),
#  ('0JQ5DAqbMKFOOxftoKZxod', 'RADAR'),
#  ('0JQ5DAqbMKFAXlCG6QvYQ4', 'Workout'),
#  ('0JQ5DAqbMKFGvOw3O4nLAf', 'K-pop'),
#  ('0JQ5DAqbMKFCuoRTxhYWow', 'Sleep'),
#  ('0JQ5DAqbMKFA6SOHvT3gck', 'Party'),
#  ('0JQ5DAqbMKFx0uLQR2okcc', 'At Home'),
#  ('0JQ5DAqbMKFCbimwdOYlsl', 'Focus'),
#  ('0JQ5DAqbMKFIVNxQgRNSg0', 'Decades'),
#  ('0JQ5DAqbMKFxXaXKP7zcDp', 'Latin'),
#  ('0JQ5DAqbMKFEZPnFQSFB1T', 'R&B'),
#  ('0JQ5DAqbMKFAUsdyVjCQuL', 'Love'),
#  ('0JQ5DAqbMKFFoimhOqWzLB', 'Kids & Family'),
#  ('0JQ5DAqbMKFDkd668ypn6O', 'Metal'),
#  ('0JQ5DAqbMKFAJ5xb0fwo9m', 'Jazz'),
#  ('0JQ5DAqbMKFQIL0AXnG5AK', 'Trending'),
#  ('0JQ5DAqbMKFziKOShCi009', 'Anime'),
#  ('0JQ5DAqbMKFPrEiAOxgac3', 'Classical'),
#  ('0JQ5DAqbMKFy78wprEpAjl', 'Folk & Acoustic'),
#  ('0JQ5DAqbMKFKLfwjuJMoNC', 'Country'),
#  ('0JQ5DAqbMKFIxnofjQmnmn', 'Disney'),
#  ('0JQ5DAqbMKFIpEuaCnimBj', 'Soul'),
#  ('0JQ5DAqbMKFCfObibaOZbv', 'Gaming'),
#  ('0JQ5DAqbMKFGnsSfvg90Wo', 'GLOW'),
#  ('0JQ5DAqbMKFOzQeOmemkuw', 'TV & Movies'),
#  ('0JQ5DAqbMKFEOEBCABAxo9', 'Netflix'),
#  ('0JQ5DAqbMKFRieVZLLoo9m', 'Instrumental'),
#  ('0JQ5DAqbMKFLb2EqgLtpjC', 'Wellness'),
#  ('0JQ5DAqbMKFAjfauKLOZiv', 'Punk'),
#  ('0JQ5DAqbMKFLjmiZRss79w', 'Ambient'),
#  ('0JQ5DAqbMKFQiK2EHwyjcU', 'Blues'),
#  ('0JQ5DAqbMKFRY5ok2pxXJ0', 'Cooking & Dining'),
#  ('0JQ5DAqbMKFFtlLYUHv8bT', 'Alternative'),
#  ('0JQ5DAqbMKFAQy4HL4XU2D', 'Travel'),
#  ('0JQ5DAqbMKFJKoGyUMo2hE', 'Reggae'),
#  ('0JQ5DAqbMKFObNLOHydSW8', 'Caribbean'),
#  ('0JQ5DAqbMKFNQ0fGp4byGU', 'Afro'),
#  ('0JQ5DAqbMKFSCjnQr8QZ3O', 'Songwriters'),
#  ('0JQ5DAqbMKFI3pNLtYMD9S', 'Nature & Noise'),
#  ('0JQ5DAqbMKFFsW9N8maB6z', 'Funk & Disco'),
#  ('0JQ5DAqbMKFDBgllo2cUIN', 'Spotify Singles'),
#  ('0JQ5DAqbMKFRKBHIxJ5hMm', 'Tastemakers')]

# %% [markdown]
# > save to csv, convert the list of tuples to a DataFrame

# %%
df = pd.DataFrame(all_category_ids, columns=['category_id', 'category_name'])
df.to_csv('./cache/2_Category_Ids.csv', index=False)

# %%
df
# Out:
#                category_id     category_name
# 0   0JQ5DAt0tbjZptfcdMSKl3      Made For You
# 1   0JQ5DAqbMKFz6FAsUtgAab      New Releases
# 2   0JQ5DAqbMKFQ00XGBls6ym           Hip-Hop
# 3   0JQ5DAqbMKFEC4WFtoNRpw               Pop
# 4   0JQ5DAqbMKFzHmL4tf05da              Mood
# 5   0JQ5DAqbMKFDXXwE9BDJAr              Rock
# 6   0JQ5DAudkNjCgYMM0TZXDw            Charts
# 7   0JQ5DAqbMKFIRybaNTYXXy        In the car
# 8   0JQ5DAqbMKFHOzuVTgTizF  Dance/Electronic
# 9   0JQ5DAqbMKFFzDl7qN9Apr             Chill
# 10  0JQ5DAqbMKFCWjUTdzaG0e             Indie
# 11  0JQ5DAtOnAEpjOgUKwXyxj          Discover
# 12  0JQ5DAqbMKFImHYGo3eTSg       Fresh Finds
# 13  0JQ5DAqbMKFPw634sFwguI             EQUAL
# 14  0JQ5DAqbMKFOOxftoKZxod             RADAR
# 15  0JQ5DAqbMKFAXlCG6QvYQ4           Workout
# 16  0JQ5DAqbMKFGvOw3O4nLAf             K-pop
# 17  0JQ5DAqbMKFCuoRTxhYWow             Sleep
# 18  0JQ5DAqbMKFA6SOHvT3gck             Party
# 19  0JQ5DAqbMKFx0uLQR2okcc           At Home
# 20  0JQ5DAqbMKFCbimwdOYlsl             Focus
# 21  0JQ5DAqbMKFIVNxQgRNSg0           Decades
# 22  0JQ5DAqbMKFxXaXKP7zcDp             Latin
# 23  0JQ5DAqbMKFEZPnFQSFB1T               R&B
# 24  0JQ5DAqbMKFAUsdyVjCQuL              Love
# 25  0JQ5DAqbMKFFoimhOqWzLB     Kids & Family
# 26  0JQ5DAqbMKFDkd668ypn6O             Metal
# 27  0JQ5DAqbMKFAJ5xb0fwo9m              Jazz
# 28  0JQ5DAqbMKFQIL0AXnG5AK          Trending
# 29  0JQ5DAqbMKFziKOShCi009             Anime
# 30  0JQ5DAqbMKFPrEiAOxgac3         Classical
# 31  0JQ5DAqbMKFy78wprEpAjl   Folk & Acoustic
# 32  0JQ5DAqbMKFKLfwjuJMoNC           Country
# 33  0JQ5DAqbMKFIxnofjQmnmn            Disney
# 34  0JQ5DAqbMKFIpEuaCnimBj              Soul
# 35  0JQ5DAqbMKFCfObibaOZbv            Gaming
# 36  0JQ5DAqbMKFGnsSfvg90Wo              GLOW
# 37  0JQ5DAqbMKFOzQeOmemkuw       TV & Movies
# 38  0JQ5DAqbMKFEOEBCABAxo9           Netflix
# 39  0JQ5DAqbMKFRieVZLLoo9m      Instrumental
# 40  0JQ5DAqbMKFLb2EqgLtpjC          Wellness
# 41  0JQ5DAqbMKFAjfauKLOZiv              Punk
# 42  0JQ5DAqbMKFLjmiZRss79w           Ambient
# 43  0JQ5DAqbMKFQiK2EHwyjcU             Blues
# 44  0JQ5DAqbMKFRY5ok2pxXJ0  Cooking & Dining
# 45  0JQ5DAqbMKFFtlLYUHv8bT       Alternative
# 46  0JQ5DAqbMKFAQy4HL4XU2D            Travel
# 47  0JQ5DAqbMKFJKoGyUMo2hE            Reggae
# 48  0JQ5DAqbMKFObNLOHydSW8         Caribbean
# 49  0JQ5DAqbMKFNQ0fGp4byGU              Afro
# 50  0JQ5DAqbMKFSCjnQr8QZ3O       Songwriters
# 51  0JQ5DAqbMKFI3pNLtYMD9S    Nature & Noise
# 52  0JQ5DAqbMKFFsW9N8maB6z      Funk & Disco
# 53  0JQ5DAqbMKFDBgllo2cUIN   Spotify Singles
# 54  0JQ5DAqbMKFRKBHIxJ5hMm       Tastemakers
